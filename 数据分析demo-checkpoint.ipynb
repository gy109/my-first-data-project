# %%
import requests 
from lxml import etree

# %%
#发起请求
response=requests.get('https://zhuhai.qfang.com/rent')
print(response.status_code)
# Out:
# 200

# %%
#解析内容
selector=etree.HTML(response.text)
title=selector.xpath('//*[@id="cycleListings"]/ul/li[1]/div[2]/div[1]/a/text()')[0]
title
# Out:
# '华策南湾国际 4房2厅2卫 精装 139.39平'
